# %% [markdown]
# ## Importing Libraries

# %%
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Path to the competition data

# %%
DATA_DIR_COMPETITION = Path('/Users/joscha/Library/Mobile Documents/com~apple~CloudDocs/Studienarbeit/Daten')

# %% [markdown]
# ### Path to the original data

# %%
DATA_DIR_ORIGINAL = Path('/Users/joscha/Library/Mobile Documents/com~apple~CloudDocs/Studienarbeit/Original Datensatz')

# %% [markdown]
# ### Loading the data

# %%
competition_data = pd.read_csv(DATA_DIR_COMPETITION / 'train_values.csv', index_col='building_id')
original_data = pd.read_csv(DATA_DIR_ORIGINAL / 'csv_building_structure.csv', index_col='building_id')

# %% [markdown]
# ### Overview of the data

# %%
# Competition Data
competition_data
#competition_data.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906                    6             487           12198
# 28830                     8             900            2812
# 94947                    21             363            8973
# 590882                   22             418           10694
# 201944                   11             131            1488
# ...                     ...             ...             ...
# 688636                   25            1335            1621
# 669485                   17             715            2060
# 602512                   17              51            8163
# 151409                   26              39            1851
# 747594                   21               9            9101
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 802906                         2   30                6                  5
# ...

# %%
# Original Data
original_data
#original_data.head()
# Out:
#               district_id  vdcmun_id  ward_id  count_floors_pre_eq  \
# building_id
# 120101000011           12       1207   120703                    1
# 120101000021           12       1207   120703                    1
# 120101000031           12       1207   120703                    1
# 120101000041           12       1207   120703                    1
# 120101000051           12       1207   120703                    1
# ...                   ...        ...      ...                  ...
# 366709001241           36       3603   360302                    2
# 366709001251           36       3603   360302                    2
# 366709001261           36       3603   360302                    2
# 366709001271           36       3603   360302                    2
# 366709001281           36       3603   360302                    2
#
#               count_floors_post_eq  age_building  plinth_area_sq_ft  \
# building_id
# ...

# %% [markdown]
# ### Compare Datasets

# %%
# Values of the original dataset
unique_values_district_id = original_data["district_id"].value_counts()
unique_values_vdcmun_id = original_data["vdcmun_id"].value_counts()
uniquq_values_ward_id = original_data["ward_id"].value_counts()
print(len(unique_values_district_id))
print(len(unique_values_vdcmun_id))
print(len(uniquq_values_ward_id))
# Out:
# 11
# 110
# 945

# %%
# Values of the competition dataset
unique_values_geo_lvl_1_id = competition_data["geo_level_1_id"].value_counts()
unique_values_geo_lvl_2_id = competition_data["geo_level_2_id"].value_counts()
uniquq_values_geo_lvl_3_id = competition_data["geo_level_3_id"].value_counts()
print(len(unique_values_geo_lvl_1_id))
print(len(unique_values_geo_lvl_2_id))
print(len(uniquq_values_geo_lvl_3_id))
# Out:
# 31
# 1414
# 11595
